# %%
import numpy as np

# %%
# création de la marche aléatoire 1D

def marche_aléatoire(p,N):  # avec 0<p<1 et N entier naturel
    A = np.random.random(N)  # ici on fait avec une uniforme continue qui renvoie des valeurs entre 0 et 1 
                             # en comparant une uniforme continue Y de [0,1] à une proba 'p' cela revient à simuler une Bernoulli X de paramètre 'p' (car P(Y=<p) = p = P(X=1))

# %%
a = np.random.random(8)
print (a)
# Out:
# [0.4312382  0.1759895  0.83474576 0.13700772 0.41854388 0.15111904
#  0.35967171 0.08196842]
