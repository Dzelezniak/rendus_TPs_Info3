# %%
# importation des bibliothèques

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importation du fichier

data_presidentielles = pd.read_csv("elections-presidentielles-2017-1ertour.csv",  sep =';') # pour ouvrir le fichier csv
print(data_presidentielles)

data_presidentielles.columns    # pour voir les noms des colonnes
# Out:
#     ID_BVOTE         SCRUTIN  ANNEE  TOUR        DATE  NUM_CIRC  NUM_QUARTIER  \
# 0      15-49  Présidentielle   2017     1  2007-04-23        13            57
# 1      15-51  Présidentielle   2017     1  2007-04-23        13            57
# 2      15-77  Présidentielle   2017     1  2007-04-23        13            58
# 3      16-42  Présidentielle   2017     1  2007-04-23        14            63
# 4      16-55  Présidentielle   2017     1  2007-04-23         4            64
# ..       ...             ...    ...   ...         ...       ...           ...
# 891    18-64  Présidentielle   2017     1  2007-04-23        17            72
# 892    18-67  Présidentielle   2017     1  2007-04-23         3            69
# 893    19-24  Présidentielle   2017     1  2007-04-23        16            75
# 894    20-21  Présidentielle   2017     1  2007-04-23        15            78
# 895    20-33  Présidentielle   2017     1  2007-04-23        15            77
#
#      NUM_ARROND  NUM_BUREAU  NB_PROCU  ...  HAMON Benoît  ARTHAUD Nathalie  \
# 0            15          49        32  ...           107                 7
# 1            15          51        68  ...           126                 7
# 2            15          77        55  ...            90                 4
# 3            16          42        60  ...            29                 2
# 4            16          55        98  ...            27                 0
# ..          ...         ...       ...  ...           ...               ...
# 891          18          64        44  ...           145                 7
# 892          18          67        60  ...           163                 2
# 893          19          24        42  ...           129                 3
# 894          20          21        43  ...           125                 2
# 895          20          33        23  ...           109                 5
#
#      POUTOU Philippe  CHEMINADE Jacques  LASSALLE Jean  MÉLENCHON Jean-Luc  \
# 0                 13                  1             10                 272
# 1                  4                  1              6                 168
# 2                  5                  1              8                 224
# 3                  4                  2              2                  49
# 4                  1                  0              4                  44
# ..               ...                ...            ...                 ...
# 891               19                  1             10                 502
# 892               20                  2              1                 304
# 893               14                  2              7                 289
# 894                8                  3              5                 312
# 895                6                  2              7                 332
#
#      ASSELINEAU François  FILLON François  \
# 0                      9              208
# 1                     15              407
# 2                     15              366
# 3                      7              554
# 4                      3              817
# ..                   ...              ...
# 891                   23              120
# 892                   16              159
# 893                    7              311
# 894                   17              157
# 895                   16              103
#
#                                              geo_shape  \
# 0    {"type": "Polygon", "coordinates": [[[2.291134...
# 1    {"type": "Polygon", "coordinates": [[[2.296524...
# 2    {"type": "Polygon", "coordinates": [[[2.281700...
# 3    {"type": "Polygon", "coordinates": [[[2.259387...
# 4    {"type": "Polygon", "coordinates": [[[2.275841...
# ..                                                 ...
# 891  {"type": "Polygon", "coordinates": [[[2.359424...
# 892  {"type": "Polygon", "coordinates": [[[2.339433...
# 893  {"type": "Polygon", "coordinates": [[[2.393886...
# 894  {"type": "Polygon", "coordinates": [[[2.412624...
# 895  {"type": "Polygon", "coordinates": [[[2.409430...
#
#                     geo_point_2d
# 0     48.8284597999,2.2947592188
# 1    48.8330859695,2.29994195103
# 2    48.8374011926,2.27208045955
# 3    48.8416058361,2.26026627937
# 4    48.8675564159,2.27354998682
# ..                           ...
# 891  48.8954256652,2.36069257185
# 892  48.8955565768,2.33825775116
# 893  48.8853293542,2.39198328468
# 894  48.8759066441,2.40819867494
# 895  48.8621036956,2.41198612573
#
# [896 rows x 29 columns]
# Index(['ID_BVOTE', 'SCRUTIN', 'ANNEE', 'TOUR', 'DATE', 'NUM_CIRC',
#        'NUM_QUARTIER', 'NUM_ARROND', 'NUM_BUREAU', 'NB_PROCU', 'NB_INSCR',
#        'NB_EMARG', 'NB_VOTANT', 'NB_BL', 'NB_NUL', 'NB.EXPRIM',
#        'DUPONT-AIGNAN Nicolas', 'LE PEN Marine', 'MACRON Emmanuel',
#        'HAMON Benoît', 'ARTHAUD Nathalie', 'POUTOU Philippe',
#        'CHEMINADE Jacques', 'LASSALLE Jean', 'MÉLENCHON Jean-Luc',
#        'ASSELINEAU François', 'FILLON François', 'geo_shape', 'geo_point_2d'],
#       dtype='object')

# %%
# 1.voix pour JL MELENCHON

voix_JL = data_presidentielles[['MÉLENCHON Jean-Luc']]  # on extrait la colonne 'MÉLENCHON Jean-Luc'
display(voix_JL)    # 'display' permet d'afficher
# Out:
#      MÉLENCHON Jean-Luc
# 0                   272
# 1                   168
# 2                   224
# 3                    49
# 4                    44
# ..                  ...
# 891                 502
# 892                 304
# 893                 289
# 894                 312
# 895                 332
#
# [896 rows x 1 columns]

# %%
# 2.représentatione en histogramme

voix_JL.hist(bins = 20) # histogramme avec 'nb de voix' en abscisses et, par 'intervalle de voix [x, x + dx]', le 'nb d'éléments qui se trouvent dans [x, x + dx]' en ordpnnées
# Out:
# array([[<Axes: title={'center': 'MÉLENCHON Jean-Luc'}>]], dtype=object)

# %%
# 3.nb de bureaux de vote par arrondissement

data_ar = data_presidentielles[['ID_BVOTE','NUM_ARROND']]
display(data_ar)
data_ar.value_counts()
# Out:
#     ID_BVOTE  NUM_ARROND
# 0      15-49          15
# 1      15-51          15
# 2      15-77          15
# 3      16-42          16
# 4      16-55          16
# ..       ...         ...
# 891    18-64          18
# 892    18-67          18
# 893    19-24          19
# 894    20-21          20
# 895    20-33          20
#
# [896 rows x 2 columns]
# ID_BVOTE  NUM_ARROND
# 1-1       1             1
# 1-10      1             1
# 18-68     18            1
# 18-7      18            1
# 18-8      18            1
#                        ..
# 15-15     15            1
# 15-16     15            1
# 15-17     15            1
# 15-18     15            1
# 9-9       9             1
# Name: count, Length: 896, dtype: int64
